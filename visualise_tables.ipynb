# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

q_table = np.load('infinite_q_table.npy')

q_table_no_ace = q_table[:][0]
q_table_ace = q_table[:][1]

print(q_table)
# Out:
# [[[1.62280282e+057             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[1.29517104e+055             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[1.14242017e+064             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[1.00852941e+066             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[3.37060138e+070             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[2.86527722e+076             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[            inf             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[1.55462142e+083             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[            inf             inf]
#   [0.00000000e+000 0.00000000e+000]]
#
#  [[1.34412169e+304 5.05895624e+054]
#   [5.02458010e+060             inf]]
#
#  [[8.13353280e+052             inf]
#   [5.60183932e+010 5.20577215e+094]]
#
#  [[            inf 1.04380780e+057]
#   [3.81452703e+010 2.28047262e+095]]
#
#  [[            inf 4.70172275e+055]
#   [1.58742544e+018 3.25313802e+095]]
#
#  [[            inf 2.95501145e+051]
#   [5.00764710e+012 2.59866523e+088]]
#
#  [[            inf 2.92300652e+046]
#   [2.32568218e+013 5.94045215e+095]]
#
#  [[            inf 1.23757554e+045]
#   [5.96641285e+103 4.51900950e+072]]
#
#  [[1.22052270e+210 4.89236578e+024]
#   [1.23522304e+107 1.20934206e+015]]
#
#  [[            inf 4.29141671e+037]
#   [4.30207839e+010 5.09806554e+075]]
#
#  [[3.30049528e+233 1.15962290e+026]
#   [2.90499910e+129 3.18633928e+014]]]

# %%
q_policy = np.load('infinite_policy.npy')
print(q_policy.shape)
policy_df = pd.DataFrame(q_policy, columns=['No Ace', 'Ace'], index=np.arange(2,21))
policy_df
# Out:
# (19, 2)
#     No Ace  Ace
# 2      1.0  0.0
# 3      1.0  0.0
# 4      1.0  0.0
# 5      1.0  0.0
# 6      1.0  0.0
# 7      1.0  0.0
# 8      0.0  0.0
# 9      1.0  0.0
# 10     0.0  0.0
# 11     0.0  1.0
# 12     1.0  1.0
# 13     0.0  1.0
# 14     0.0  1.0
# 15     0.0  1.0
# 16     0.0  1.0
# 17     0.0  0.0
# 18     0.0  0.0
# 19     0.0  1.0
# 20     0.0  0.0
